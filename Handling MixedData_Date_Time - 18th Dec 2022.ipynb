# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#   Cabin            Ticket number  Survived
# 0   NaN         A/5 21171      5         0
# 1   C85          PC 17599      3         1
# 2   NaN  STON/O2. 3101282      6         1
# 3  C123            113803      3         1
# 4   NaN            373450      A         0

# %%
df['number'].unique()
# Out:
# array(['5', '3', '6', 'A', '2', '1', '4'], dtype=object)

# %%
df['number'].value_counts()
# Out:
# A    139
# 6    131
# 1    129
# 2    126
# 4    126
# 5    123
# 3    117
# Name: number, dtype: int64

# %%
fig = df['number'].value_counts().plot.bar()
fig.set_title("Passengers travelling with Titan")
# Out:
# Text(0.5, 1.0, 'Passengers travelling with Titan')

# %%
df['number_numeric'] = pd.to_numeric(df['number'],errors= 'coerce', downcast='integer')

# %%
df['number_numeric1'] = pd.to_numeric(df['number'],errors= 'coerce')

# %%
df = df.drop(['number_numeric1'], axis=1)

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_numeric
# 0   NaN         A/5 21171      5         0             5.0
# 1   C85          PC 17599      3         1             3.0
# 2   NaN  STON/O2. 3101282      6         1             6.0
# 3  C123            113803      3         1             3.0
# 4   NaN            373450      A         0             NaN

# %%
df.head(20)
# Out:
#    Cabin            Ticket number  Survived  number_numeric
# 0    NaN         A/5 21171      5         0             5.0
# 1    C85          PC 17599      3         1             3.0
# 2    NaN  STON/O2. 3101282      6         1             6.0
# 3   C123            113803      3         1             3.0
# 4    NaN            373450      A         0             NaN
# 5    NaN            330877      2         0             2.0
# 6    E46             17463      2         0             2.0
# 7    NaN            349909      5         0             5.0
# 8    NaN            347742      1         1             1.0
# 9    NaN            237736      A         1             NaN
# 10    G6           PP 9549      1         1             1.0
# 11  C103            113783      1         1             1.0
# 12   NaN         A/5. 2151      3         0             3.0
# 13   NaN            347082      3         0             3.0
# 14   NaN            350406      5         0             5.0
# ...

# %%
df['number_categorical'] = np.where(df['number_numeric'].isnull(),df['number'],np.nan)

# %%
df.tail(20)
# Out:
#            Cabin            Ticket number  Survived  number_numeric  \
# 871          D35             11751      1         1             1.0
# 872  B51 B53 B55               695      6         0             6.0
# 873          NaN            345765      6         0             6.0
# 874          NaN         P/PP 3381      4         1             4.0
# 875          NaN              2667      A         1             NaN
# 876          NaN              7534      A         0             NaN
# 877          NaN            349212      5         0             5.0
# 878          NaN            349217      6         0             6.0
# 879          C50             11767      A         1             NaN
# 880          NaN            230433      4         1             4.0
# 881          NaN            349257      A         0             NaN
# 882          NaN              7552      5         0             5.0
# 883          NaN  C.A./SOTON 34068      1         0             1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cabin               204 non-null    object
#  1   Ticket              891 non-null    object
#  2   number              891 non-null    object
#  3   Survived            891 non-null    int64
#  4   number_numeric      752 non-null    float64
#  5   number_categorical  139 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 41.9+ KB

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['cabin_num'] = df['Cabin'].str.extract('(\d+)')
df['cabin_cat'] = df['Cabin'].str[0]

# %%
df.head(20)
# Out:
#    Cabin            Ticket number  Survived  number_numeric  \
# 0    NaN         A/5 21171      5         0             5.0
# 1    C85          PC 17599      3         1             3.0
# 2    NaN  STON/O2. 3101282      6         1             6.0
# 3   C123            113803      3         1             3.0
# 4    NaN            373450      A         0             NaN
# 5    NaN            330877      2         0             2.0
# 6    E46             17463      2         0             2.0
# 7    NaN            349909      5         0             5.0
# 8    NaN            347742      1         1             1.0
# 9    NaN            237736      A         1             NaN
# 10    G6           PP 9549      1         1             1.0
# 11  C103            113783      1         1             1.0
# 12   NaN         A/5. 2151      3         0             3.0
# 13   NaN            347082      3         0             3.0
# 14   NaN            350406      5         0             5.0
# ...

# %%
df['cabin_cat'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
df['ticket_num'] = df['Ticket'].apply(lambda s:s.split()[-1])
df['ticket_num'] = pd.to_numeric(df['ticket_num'],errors= 'coerce', downcast='integer')

df['ticket_cat'] = df['Ticket'].apply(lambda s:s.split()[0])
df['ticket_cat'] = np.where(df['ticket_cat'].str.isdigit(), np.nan, df['ticket_cat'])

# %%
df.head(20)
# Out:
#    Cabin            Ticket number  Survived  number_numeric  \
# 0    NaN         A/5 21171      5         0             5.0
# 1    C85          PC 17599      3         1             3.0
# 2    NaN  STON/O2. 3101282      6         1             6.0
# 3   C123            113803      3         1             3.0
# 4    NaN            373450      A         0             NaN
# 5    NaN            330877      2         0             2.0
# 6    E46             17463      2         0             2.0
# 7    NaN            349909      5         0             5.0
# 8    NaN            347742      1         1             1.0
# 9    NaN            237736      A         1             NaN
# 10    G6           PP 9549      1         1             1.0
# 11  C103            113783      1         1             1.0
# 12   NaN         A/5. 2151      3         0             3.0
# 13   NaN            347082      3         0             3.0
# 14   NaN            350406      5         0             5.0
# ...

# %%
df.columns
# Out:
# Index(['Cabin', 'Ticket', 'number', 'Survived', 'number_numeric',
#        'number_categorical', 'cabin_num', 'cabin_cat', 'ticket_num',
#        'ticket_cat'],
#       dtype='object')

# %%
# drop - 'Cabin', 'Ticket', 'number'
df = df.drop(['Cabin', 'Ticket', 'number'], axis=1)

# %%
df.head()
# Out:
#    Survived  number_numeric number_categorical cabin_num cabin_cat  \
# 0         0             5.0                NaN       NaN       NaN
# 1         1             3.0                NaN        85         C
# 2         1             6.0                NaN       NaN       NaN
# 3         1             3.0                NaN       123         C
# 4         0             NaN                  A       NaN       NaN
#
#    ticket_num ticket_cat
# 0     21171.0        A/5
# 1     17599.0         PC
# 2   3101282.0   STON/O2.
# 3    113803.0        NaN
# 4    373450.0        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Survived            891 non-null    int64
#  1   number_numeric      752 non-null    float64
#  2   number_categorical  139 non-null    object
#  3   cabin_num           200 non-null    object
#  4   cabin_cat           204 non-null    object
#  5   ticket_num          887 non-null    float64
#  6   ticket_cat          230 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 48.9+ KB

# %% [markdown]
# # Handling Date and Time

# %%
date = pd.read_csv('orders.csv')
time = pd.read_csv('messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
# Treatment 
# 1) date
# convert object into datetime format
date['date'] = pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
# extract year
date['year'] = date['date'].dt.year
date.sample(5)
# Out:
#           date  product_id  city_id  orders  year
# 99  2019-04-13        6206        2      24  2019
# 376 2018-09-01        5738       13      22  2018
# 905 2018-08-22         133       16       2  2018
# 223 2019-07-18        4529       20       5  2019
# 552 2019-02-04        5955       16       3  2019

# %%
# Extract month
date['month'] = date['date'].dt.month
date.head()
# Out:
#         date  product_id  city_id  orders  year  month
# 0 2019-12-10        5628       25       3  2019     12
# 1 2018-08-15        3646       14     157  2018      8
# 2 2018-10-23        1859       25       1  2018     10
# 3 2019-08-17        7292       25       1  2019      8
# 4 2019-01-06        4344       25       3  2019      1

# %%
# Month Name
date['month_name'] = date['date'].dt.month_name()
date.head()
# Out:
#         date  product_id  city_id  orders  year  month month_name
# 0 2019-12-10        5628       25       3  2019     12   December
# 1 2018-08-15        3646       14     157  2018      8     August
# 2 2018-10-23        1859       25       1  2018     10    October
# 3 2019-08-17        7292       25       1  2019      8     August
# 4 2019-01-06        4344       25       3  2019      1    January

# %%
# extract day
date['date_day'] = date['date'].dt.day
date.head()
# Out:
#         date  product_id  city_id  orders  year  month month_name  date_day
# 0 2019-12-10        5628       25       3  2019     12   December        10
# 1 2018-08-15        3646       14     157  2018      8     August        15
# 2 2018-10-23        1859       25       1  2018     10    October        23
# 3 2019-08-17        7292       25       1  2019      8     August        17
# 4 2019-01-06        4344       25       3  2019      1    January         6

# %%
# day of the week
date['date_week'] = date['date'].dt.dayofweek
date.head()
# Out:
#         date  product_id  city_id  orders  year  month month_name  date_day  \
# 0 2019-12-10        5628       25       3  2019     12   December        10
# 1 2018-08-15        3646       14     157  2018      8     August        15
# 2 2018-10-23        1859       25       1  2018     10    October        23
# 3 2019-08-17        7292       25       1  2019      8     August        17
# 4 2019-01-06        4344       25       3  2019      1    January         6
#
#    date_week
# 0          1
# 1          2
# 2          1
# 3          5
# 4          6

# %%
date['date_dow_name'] = date['date'].dt.day_name()
date.head()
# Out:
#         date  product_id  city_id  orders  year  month month_name  date_day  \
# 0 2019-12-10        5628       25       3  2019     12   December        10
# 1 2018-08-15        3646       14     157  2018      8     August        15
# 2 2018-10-23        1859       25       1  2018     10    October        23
# 3 2019-08-17        7292       25       1  2019      8     August        17
# 4 2019-01-06        4344       25       3  2019      1    January         6
#
#    date_week date_dow_name
# 0          1       Tuesday
# 1          2     Wednesday
# 2          1       Tuesday
# 3          5      Saturday
# 4          6        Sunday

# %%
date.tail(20)
# Out:
#           date  product_id  city_id  orders  year  month month_name  date_day  \
# 980 2018-08-03        3783       14       3  2018      8     August         3
# 981 2019-06-17        7526       14      12  2019      6       June        17
# 982 2019-06-22         354       13       2  2019      6       June        22
# 983 2019-08-02        6399        0       1  2019      8     August         2
# 984 2019-11-23         528        0       3  2019     11   November        23
# 985 2018-12-08        5486       14       1  2018     12   December         8
# 986 2019-08-18        1406       14      26  2019      8     August        18
# 987 2018-12-25          27       10      41  2018     12   December        25
# 988 2019-02-03        5022        2      43  2019      2   February         3
# 989 2019-02-20         438       22      28  2019      2   February        20
# 990 2018-10-28        3034        0       1  2018     10    October        28
# ...

# %%
# is weekend ?
date['date_is_weekend'] = np.where(date['date_dow_name'].isin(['Sunday','Saturday']),1,0)
date.head()
# Out:
#         date  product_id  city_id  orders  year  month month_name  date_day  \
# 0 2019-12-10        5628       25       3  2019     12   December        10
# 1 2018-08-15        3646       14     157  2018      8     August        15
# 2 2018-10-23        1859       25       1  2018     10    October        23
# 3 2019-08-17        7292       25       1  2019      8     August        17
# 4 2019-01-06        4344       25       3  2019      1    January         6
#
#    date_week date_dow_name  date_is_weekend
# 0          1       Tuesday                0
# 1          2     Wednesday                0
# 2          1       Tuesday                0
# 3          5      Saturday                1
# 4          6        Sunday                1

# %%
date['date_week'] = date['date'].dt.week
date.head()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_52692\79670112.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   date['date_week'] = date['date'].dt.week
#         date  product_id  city_id  orders  year  month month_name  date_day  \
# 0 2019-12-10        5628       25       3  2019     12   December        10
# 1 2018-08-15        3646       14     157  2018      8     August        15
# 2 2018-10-23        1859       25       1  2018     10    October        23
# 3 2019-08-17        7292       25       1  2019      8     August        17
# 4 2019-01-06        4344       25       3  2019      1    January         6
#
#    date_week date_dow_name  date_is_weekend
# 0         50       Tuesday                0
# 1         33     Wednesday                0
# 2         43       Tuesday                0
# 3         33      Saturday                1
# 4          1        Sunday                1

# %%
date['Quarter'] = date['date'].dt.quarter
date.head()
# Out:
#         date  product_id  city_id  orders  year  month month_name  date_day  \
# 0 2019-12-10        5628       25       3  2019     12   December        10
# 1 2018-08-15        3646       14     157  2018      8     August        15
# 2 2018-10-23        1859       25       1  2018     10    October        23
# 3 2019-08-17        7292       25       1  2019      8     August        17
# 4 2019-01-06        4344       25       3  2019      1    January         6
#
#    date_week date_dow_name  date_is_weekend  Quarter
# 0         50       Tuesday                0        4
# 1         33     Wednesday                0        3
# 2         43       Tuesday                0        4
# 3         33      Saturday                1        3
# 4          1        Sunday                1        1

# %%
date['semester'] = np.where(date['Quarter'].isin([1,2]),1,2)
date.head()
# Out:
#         date  product_id  city_id  orders  year  month month_name  date_day  \
# 0 2019-12-10        5628       25       3  2019     12   December        10
# 1 2018-08-15        3646       14     157  2018      8     August        15
# 2 2018-10-23        1859       25       1  2018     10    October        23
# 3 2019-08-17        7292       25       1  2019      8     August        17
# 4 2019-01-06        4344       25       3  2019      1    January         6
#
#    date_week date_dow_name  date_is_weekend  Quarter  semester
# 0         50       Tuesday                0        4         2
# 1         33     Wednesday                0        3         2
# 2         43       Tuesday                0        4         2
# 3         33      Saturday                1        3         2
# 4          1        Sunday                1        1         1

# %% [markdown]
# # Time

# %%
from datetime import datetime

# %%
today = datetime.today()
today
# Out:
# datetime.datetime(2022, 12, 18, 11, 47, 27, 998307)

# %%
today - date['date']
# Out:
# 0     1104 days 11:47:27.998307
# 1     1586 days 11:47:27.998307
# 2     1517 days 11:47:27.998307
# 3     1219 days 11:47:27.998307
# 4     1442 days 11:47:27.998307
#                  ...
# 995   1532 days 11:47:27.998307
# 996   1473 days 11:47:27.998307
# 997   1321 days 11:47:27.998307
# 998   1386 days 11:47:27.998307
# 999   1160 days 11:47:27.998307
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today - date['date']).dt.days
# Out:
# 0      1104
# 1      1586
# 2      1517
# 3      1219
# 4      1442
#        ...
# 995    1532
# 996    1473
# 997    1321
# 998    1386
# 999    1160
# Name: date, Length: 1000, dtype: int64

# %%
np.round((today - date['date'])/np.timedelta64(1, 'M'),0)
# Out:
# 0      36.0
# 1      52.0
# 2      50.0
# 3      40.0
# 4      47.0
#        ...
# 995    50.0
# 996    48.0
# 997    43.0
# 998    46.0
# 999    38.0
# Name: date, Length: 1000, dtype: float64

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
time['date'] = pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
time['hour'] = time['date'].dt.hour
time['mins'] = time['date'].dt.minute
time['seconds'] = time['date'].dt.second

# %%
time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  mins  seconds
# 0     0    50        0
# 1    23    40        0
# 2     0    21        0
# 3     0    31        0
# 4    23    11        0

# %%
time['time'] = time['date'].dt.time
time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  mins  seconds      time
# 0     0    50        0  00:50:00
# 1    23    40        0  23:40:00
# 2     0    21        0  00:21:00
# 3     0    31        0  00:31:00
# 4    23    11        0  23:11:00
